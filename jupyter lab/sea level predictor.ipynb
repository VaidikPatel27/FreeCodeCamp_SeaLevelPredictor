# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('epa-sea-level.csv')

# %%
df
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 129                 8.046354
# 130                 8.122973
# 131                 8.053065
# 132                 8.457058
# 133                 8.546648
#
# [134 rows x 5 columns]

# %%
# Q1

# %%
plt.scatter(df['Year'],df['CSIRO Adjusted Sea Level'])
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')
# Out:
# Text(0.5, 1.0, 'Rise in Sea Level')

# %%
# Q2

# %%
X = df['Year']
y = df['CSIRO Adjusted Sea Level']
X2 =  pd.DataFrame(range(1880,2051),columns=['year'])

# %%
res = linregress(X,y)

# %%
plt.plot(X,y,'o')
plt.plot(X2,res.intercept + res.slope*X2,linewidth=2,c='r')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')
# Out:
# Text(0.5, 1.0, 'Rise in Sea Level')

# %%
# Q3

# %%
new_df = df[df['Year']>=2000][['Year','CSIRO Adjusted Sea Level']]

# %%
X_new = new_df['Year']
y_new = new_df['CSIRO Adjusted Sea Level']
X2_new =  pd.DataFrame(range(2000,2051),columns=['year'])

# %%
res_new = linregress(X_new,y_new)

# %%
plt.plot(X_new,y_new,'o')
plt.plot(X2_new,res_new.intercept + res_new.slope*X2_new,linewidth=2,c='r')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')
# Out:
# Text(0.5, 1.0, 'Rise in Sea Level')
